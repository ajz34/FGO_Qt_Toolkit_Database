# %%
import os
import xmltodict

# %%
listdir = os.listdir("database")
for i in [300]:
    i_full = "{:03d}".format(i)
    if (i_full + ".xml") in listdir:
        xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
        xml_text = xml_read.read()
        xml_dict = xmltodict.parse(xml_text)
xml_dict
# Out:
# OrderedDict([('root',
#               OrderedDict([('basic',
#                             OrderedDict([('rarity', '3'),
#                                          ('id', '17'),
#                                          ('name_sc', '库·丘林'),
#                                          ('name_jp', 'クー·フーリン'),
#                                          ('name_en', 'Cú Chulainn'),
#                                          ('class', 'Lancer'),
#                                          ('alignments', ['秩序', '中庸']),
#                                          ('gender', '男性'),
#                                          ('attribute', '天'),
#                                          ('atk_base', '1344'),
#                                          ('hp_base', '1726'),
#                                          ('atk_4', '7239'),
#                                          ('hp_4', '9593'),
#                                          ('atk_90', '8942'),
# ...

# %%
xml_read = open("database/" + "001" + ".xml", "r", encoding="UTF-8")
xml_dict = xmltodict.parse(xml_read.read())

# %%
xml_dict["root"]["basic"]["alignments"]
# Out:
# OrderedDict([('@type', 'list'),
#              ('item',
#               [OrderedDict([('@type', 'str'), ('#text', '秩序')]),
#                OrderedDict([('@type', 'str'), ('#text', '善')])])])

# %% [markdown]
# # 灵衣补充

# %%
## Template
#   i = ???
#   i_full = "{:03d}".format(i)
#   xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
#   xml_text = xml_read.read()
#   xml_dict = xmltodict.parse(xml_text)
#   
#   costume = \
#   {
#       "costume_1" :
#       {
#           "name" :
#           {
#               "name_sc": "",
#               "name_jp": "",
#               "name_en": "",
#           },
#           "": 5,
#           "": 5,
#           "": 5,
#           "": 5,
#           "QP": 3000000,
#       },
#   },
#   
#   xml_dict["root"]["costume"] = costume
#   xml_text = xmltodict.unparse(xml_dict, pretty=True)
#   with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
#       file_xml.write(xml_text)
#       file_xml.write("\n")

# %%
i = 1
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)

costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "常夏的泳装",
            "name_jp": "常夏の水着",
            "name_en": "Swimsuit of Perpetual Summer",
        },
        "追忆的贝壳": 5,
        "八连双晶": 5,
        "大骑士勋章": 5,
        "凤凰羽毛": 5,
        "QP": 3000000,
    },
},

xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 99
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "迷人的狱长服",
            "name_jp": "魅惑の獄長ルック",
            "name_en": "Alluring Chief Warden Look",
        },
        "愚者之锁": 10,
        "蛇之宝玉": 5,
        "血之泪石": 5,
        "咒兽胆石": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 5
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "奥林匹亚体操服",
            "name_jp": "オリンピアの体操服",
            "name_en": "Olympian Bloomers",
        },
        "英雄之证": 10,
        "陨蹄铁": 5,
        "混沌之爪": 5,
        "智慧之圣甲虫像": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 183
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "少女所寻之物",
            "name_jp": "少女の捜し物",
            "name_en": "A Girl's Most Sought After",
        },
        "世界树之种": 10,
        "无间齿轮": 5,
        "凤凰羽毛": 5,
        "蛮神心脏": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 94
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "在图利法斯的回忆",
            "name_jp": "トゥリファスでの思い出",
            "name_en": "Memories of Trifas",
        },
        "龙之牙": 10,
        "大骑士勋章": 5,
        "起源的胎毛": 5,
        "龙之逆鳞": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 106
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "邪龙魔女ver新宿1999",
            "name_jp": "邪竜の魔女ver新宿1999",
            "name_en": "Wicked Dragon Witch ver. Shinjuku 1999",
        },
        "魔术髓液": 10,
        "万死的毒针": 5,
        "黑兽脂": 5,
        "蛮神心脏": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 160
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "白色玫瑰",
            "name_jp": "ホワイトローズ",
            "name_en": "White Rose",
        },
        "虚影之尘": 10,
        "凤凰羽毛": 5,
        "智慧之圣甲虫像": 5,
        "龙之逆鳞": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 96
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "基督山之选",
            "name_jp": "モンテ･クリストセレクション",
            "name_en": "Monte Cristo Selection",
        },
        "宵哭铁桩": 10,
        "追忆的贝壳": 5,
        "血之泪石": 5,
        "咒兽胆石": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 145
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "统治阶级",
            "name_jp": "エスタブリッシュメント",
            "name_en": "Establishment",
        },
        "英雄之证": 10,
        "追忆的贝壳": 5,
        "封魔之灯": 5,
        "智慧之圣甲虫像": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 13
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "夏日猎人",
            "name_jp": "夏の狩人",
            "name_en": "Summertime Hunter",
        },
        "万死的毒针": 10,
        "追忆的贝壳": 5,
        "起源的胎毛": 5,
        "精灵根": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")

# %%
i = 220
i_full = "{:03d}".format(i)
xml_read = open("database/" + i_full + ".xml", "r", encoding="UTF-8")
xml_text = xml_read.read()
xml_dict = xmltodict.parse(xml_text)
costume = \
{
    "costume_1" :
    {
        "name" :
        {
            "name_sc": "小恶魔卵肌 (2 阶段)",
            "name_jp": "小悪魔たまご肌 (2 階段)",
            "name_en": "Little Devil's Egg-colored Skin [2nd Ascension]",
        },
        "励振火药": 10,
        "巨人的指轮": 5,
        "黑兽脂": 5,
        "奇奇神酒": 5,
        "QP": 3000000,
    },
    "costume_2" :
    {
        "name" :
        {
            "name_sc": "小恶魔卵肌 (3 阶段)",
            "name_jp": "小悪魔たまご肌 (3 階段)",
            "name_en": "Little Devil's Egg-colored Skin [3rd Ascension]",
        },
        "魔术髓液": 10,
        "极光之钢": 5,
        "混沌之爪": 5,
        "蛮神心脏": 5,
        "QP": 3000000,
    },
},
xml_dict["root"]["costume"] = costume
xml_text = xmltodict.unparse(xml_dict, pretty=True)
with open("database/" + i_full + ".xml", "w", encoding="utf-8") as file_xml:
    file_xml.write(xml_text)
    file_xml.write("\n")
